# %%
#Import libraries
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#read dataset
ds=pd.read_csv('Social_Network_Ads.csv')
ds
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
ds.duplicated().sum()
# Out:
# 33

# %%
#for removing 
ds.drop_duplicates(inplace=True)

# %%
ds.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
ds.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
#Splitting into dependent and independent variable
x=ds[['Age','EstimatedSalary']]
y=ds[['Purchased']]

# %%
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [367 rows x 2 columns]

# %%
y
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [367 rows x 1 columns]

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x),columns=['Age','EstimatedSalary'])

# %%
x
# Out:
#           Age  EstimatedSalary
# 0   -1.755169        -1.489408
# 1   -0.255190        -1.460610
# 2   -1.098928        -0.798259
# 3   -1.005180        -0.395088
# 4   -1.755169         0.152072
# ..        ...              ...
# 362  0.776045        -0.855854
# 363  1.244788        -1.374216
# 364  1.151039        -1.460610
# 365 -0.161442        -1.086238
# 366  1.057291        -0.999844
#
# [367 rows x 2 columns]

# %%
#Splittting the dataset into the training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train ,y_test=train_test_split(x,y,test_size=0.1,random_state=0)

# %%
len(x_test)
# Out:
# 37

# %%
#Applying the Logistic Regression model on the traing set
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#Predict for myinput
myinput=pd.DataFrame(sc.transform([[30,150000]]),columns=['Age','EstimatedSalary'])
classifier.predict(myinput)
# Out:
# array([0], dtype=int64)

# %%
#Checking accuracy of Logistic regression model
from sklearn.metrics import accuracy_score

#Predict on the test set
y_pred=classifier.predict(x_test)

#Calculate accuracy
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy of logistic regression model:{accuracy*100:.2f}%")
# Out:
# Accuracy of logistic regression model:83.78%

# %%
#User input
age=float(input("Enter age:"))
salary=float(input("Enter Estimated salary:"))
myinput=pd.DataFrame(sc.transform([[age,salary]]),columns=['Age','EstimatedSalary'])
result=classifier.predict(myinput)
if result[0]==1:
    print("Prediction: User will purches plan")
else:
    print("Prediction: User will not purches plan")
# Out:
# Enter age: 23
# Enter Estimated salary: 15000
# Prediction: User will not purches plan
